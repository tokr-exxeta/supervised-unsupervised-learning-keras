# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %% [markdown]
# In diesem Notebook werden Sie ein CNN für die Klassifikation von "Handwritten digits" modellieren. Schaffen Sie es schon alleine? Versuchen Sie durch verändern der Neuronen/Layer eine bessere Accuracy zu erzielen.
# Achtung! Muss unbedingt in Collab auf einer GPU ausgeführt werden, sonst kann es zu langen Trainingszeiten kommen.

# %%
tf.test.is_gpu_available() # Muss True zurückgeben

# %% [markdown]
# ## Daten einlesen

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train_full.shape

# %%
y_train_full.shape

# %%
plt.imshow(X_train_full[0])
plt.title(label=y_train_full[0])
plt.show()

# %% [markdown]
# ## Train-/Test split & Normalisierung

# %%
## Ihr Code

#Durch 255 Teilen um Farbwerte zwischen 0-1 zu skalieren

# %% [markdown]
# ## Modellierung - CNN bauen

# %%
model = keras.models.Sequential([
    keras.Input(shape=[28,28,1]),
    ## Ihr Code
    keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer="sgd",metrics=["accuracy"])

# %%
X_train = X_train.reshape((-1,28,28,1))
X_valid = X_valid.reshape((-1,28,28,1))
X_test = X_test.reshape((-1,28,28,1))

# %%
history = model.fit(X_train,y_train, epochs=30, validation_data = (X_valid, y_valid))
